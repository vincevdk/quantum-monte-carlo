# %%
import numpy as np
from QMCP.functions import vmc
import matplotlib.pyplot as plt
from QMCP.functions import bootstrap
from QMCP.helium_atom import Helium_atom

alpha = np.linspace(0.05, 0.25, 6)
helium_atom = Helium_atom(6)
dim = helium_atom.dimension
E_ground, E_ground_error, variance = vmc(alpha, helium_atom)

print(E_ground)
plt.figure()
#plt.errorbar(alpha, E_ground, yerr=E_ground_error)
plt.plot(alpha, E_ground)
plt.title('ground state energy')

plt.figure()
plt.plot(alpha, variance)
plt.title('variance')
plt.show()
# Out:
# (10400000,) shape
# [-2.72101596 -3.32511619 -2.50225981 ..., -2.93865549 -2.99358669
#  -2.90445088] E_loc
# (10400000,) shape
# [-2.39921189 -3.13777222 -2.99078197 ..., -3.33068907 -2.63138849
#  -3.22303843] E_loc
# (10400000,) shape
# [-3.27406988 -2.94027442 -2.792559   ..., -2.66986926 -3.23825599
#  -2.87334176] E_loc
# (10400000,) shape
# [-3.00418567 -2.54350395 -2.69270722 ..., -2.51991623 -3.0152204
#  -2.90373486] E_loc
# (10400000,) shape
# [-2.86394873 -2.8948188  -3.21910589 ..., -3.24892842 -2.9094162
#  -2.94875474] E_loc
# (10400000,) shape
# [-3.02971517 -3.05729234 -2.75838583 ..., -2.76746869 -2.42159432
#  -2.68983914] E_loc
# [-2.87100126 -2.87755357 -2.87728548 -2.87857739 -2.88033722 -2.87632183]

# %%
import numpy as np
import matplotlib.pyplot as plt
from QMCP.functions import minimization_alpha
from QMCP.helium_atom import Helium_atom

helium_atom = Helium_atom(6)
dim = helium_atom.dimension
alpha = minimization_alpha(helium_atom)

steps = np.linspace(0,len(alpha),len(alpha))

plt.title('minimization of alpha')
plt.plot(steps,alpha, 'ro')
plt.show()
# Out:
# (10400000,) shape
# 1.18481662847 alpha
# (10400000,) shape
# 1.16957321159 alpha
# (10400000,) shape
# 1.15422886408 alpha
# (10400000,) shape
# 1.13874769078 alpha
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-3926398eb641> in <module>
#       6 helium_atom = Helium_atom(6)
#       7 dim = helium_atom.dimension
# ----> 8 alpha = minimization_alpha(helium_atom)
#       9
#      10 steps = np.linspace(0,len(alpha),len(alpha))
#
# ~/project2/Project_2/QMCP/functions/minimal_energy_finder.py in minimization_alpha(quantum_system)
#      58
#      59     print("minimum alpha = ", alpha_min)
# ---> 60     return(alpha_array)
#
# ~/project2/Project_2/QMCP/functions/minimal_energy_finder.py in derivative_E(alpha, quantum_system)
#      15
#      16 def minimization_alpha(quantum_system):
# ---> 17     """
#      18     Finds the alpha for which the local energy is minimal, using a simple
#      19     damped steepest decent method.
#
# ~/project2/Project_2/QMCP/functions/metropolis_algorithm.py in six_d_metropolis(function, N, n_walkers)
#      43         ratio = (function(r_trial) / function(r))**2
#      44         eta = np.random.uniform(0,1,(6,n_walkers))
# ---> 45         rn[:,i,:] = np.where(ratio >= 1, r_trial, (np.where(eta < ratio, r_trial, r)))
#      46         r = np.where(ratio >= 1, r_trial, (np.where(eta < ratio, r_trial, r)))
#      47
#
# KeyboardInterrupt:

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from QMCP.functions import parallel_minimization_alpha
from QMCP.helium_atom import Helium_atom

start = time.time()

alpha = parallel_minimization_alpha(Helium_atom(6))
steps = np.linspace(0,len(alpha)-1,len(alpha))
print("My work is finished, I took " + str(time.time() - start))

print(steps,'steps')
plt.title('minimization of alpha')
plt.plot(steps,alpha, 'ro')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-2b3d764310c3> in <module>
#       7 start = time.time()
#       8
# ----> 9 alpha = parallel_minimization_alpha(Helium_atom(6))
#      10 steps = np.linspace(0,len(alpha)-1,len(alpha))
#      11 print("My work is finished, I took " + str(time.time() - start))
#
# ~/project2/Project_2/QMCP/functions/parallel_minimal_energy_finder.py in parallel_minimization_alpha(quantum_system)
#      78     dif = 1.2
#      79
# ---> 80     alpha,dif = minimization_alpha(quantum_system, alpha)
#      81
#      82     differences = np.zeros((3))
#
# ~/project2/Project_2/QMCP/functions/parallel_minimal_energy_finder.py in minimization_alpha(quantum_system, alpha_min)
#      37
#      38     keep = alpha_min
# ---> 39     der_E, E_ground = derivative_E(alpha_min, quantum_system)
#      40     alpha_min = alpha_min - gamma * der_E
#      41
#
# ~/project2/Project_2/QMCP/functions/parallel_minimal_energy_finder.py in derivative_E(alpha, quantum_system)
#      15         prob_dens = one_d_metropolis(f,50000,400)
#      16     else:
# ---> 17         prob_dens = three_d_metropolis(f,50000,400)
#      18
#      19     E = quantum_system.E_loc(alpha, prob_dens)
#
# ~/project2/Project_2/QMCP/functions/metropolis_algorithm.py in three_d_metropolis(function, N, n_walkers)
#      26         trial_displacement = displacement + (0.2*(np.random.rand(3,n_walkers)*4-2))
#      27         x_trial = np.linalg.norm(trial_displacement, axis=0)
# ---> 28         r = (function(x_trial)/function(x[i-1]))**2
#      29         eta = np.random.uniform(0,1,size = n_walkers)
#      30         x[i] = np.where(r >= 1, x_trial, (np.where(eta < r, x_trial, x[i-1])))
#
# ~/project2/Project_2/QMCP/functions/parallel_minimal_energy_finder.py in <lambda>(R)
#      11
#      12 def derivative_E(alpha, quantum_system):
# ---> 13     f = lambda R: quantum_system.trial_wave_function(alpha, R)
#      14     if quantum_system.dimension == 1:
#      15         prob_dens = one_d_metropolis(f,50000,400)
#
# ~/project2/Project_2/QMCP/helium_atom/helium_atom.py in trial_wave_function(self, alpha, r)
#      24         trial_wave_function: function with three variables
#      25         """
# ---> 26         r1 = np.linalg.norm(r[:3,:], axis = 0)
#      27         r2 = np.linalg.norm(r[3:,:], axis = 0)
#      28         r12 = np.linalg.norm(r[:3,:]-r[3:,:], axis = 0)
#
# IndexError: too many indices for array
