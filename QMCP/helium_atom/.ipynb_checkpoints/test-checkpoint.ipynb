# %%
import numpy as np
from QMCP.functions import vmc
import matplotlib.pyplot as plt
from QMCP.functions import bootstrap
from QMCP.helium_atom import Helium_atom

N = 30000
n_walkers = 400

alpha = np.linspace(0.05, 0.25, 6)
helium_atom = Helium_atom(6)

E_ground, E_ground_error, variance, var_error = vmc(alpha, helium_atom, N, n_walkers)

print(E_ground)
plt.figure()
plt.errorbar(alpha, E_ground, yerr=E_ground_error)
#plt.plot(alpha, E_ground)
plt.title('ground state energy')

plt.figure()
plt.errorbar(alpha, variance, yerr=var_error)
#plt.plot(alpha, variance)
plt.title('variance')
plt.show()
# Out:
# (10400000,) shape
# [-3.14515755 -3.66900339 -3.62129851 ..., -2.96224574 -2.61269836
#  -2.57863015] E_loc
# (10400000,) shape
# [-2.72962202 -2.85362239 -3.35182112 ..., -2.74434181 -2.93281341
#  -2.50106768] E_loc
# (10400000,) shape
# [-2.65602466 -3.42400712 -3.82230801 ..., -3.11628875 -2.58657169
#  -3.18262393] E_loc
# (10400000,) shape
# [-2.58190914 -2.75450888 -2.88413634 ..., -3.70313323 -2.81463278
#  -2.73824894] E_loc
# (10400000,) shape
# [-3.02108895 -2.95541525 -3.54394233 ..., -3.07703471 -3.09687352
#  -2.81982179] E_loc
# (10400000,) shape
# [-3.15480575 -2.67611098 -3.1570466  ..., -2.98087827 -2.77244051
#  -3.16024646] E_loc
# [-2.87217201 -2.87804746 -2.87843186 -2.88018643 -2.87853643 -2.87753815]

# %%
import numpy as np
import matplotlib.pyplot as plt
from QMCP.functions import minimization_alpha
from QMCP.helium_atom import Helium_atom

N = 30000
n_walkers = 400

helium_atom = Helium_atom(6)
alpha = minimization_alpha(helium_atom, N, n_walkers)

steps = np.linspace(0,len(alpha),len(alpha))

plt.title('minimization of alpha')
plt.plot(steps,alpha, 'ro')
plt.show()
# Out:
# 1.12375047142 alpha
# 1.04665348947 alpha
# 0.967405440585 alpha
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-be480c6050d2> in <module>
#       8
#       9 helium_atom = Helium_atom(6)
# ---> 10 alpha = minimization_alpha(helium_atom, N, n_walkers)
#      11
#      12 steps = np.linspace(0,len(alpha),len(alpha))
#
# ~/project2/Project_2/QMCP/functions/minimal_energy_finder.py in minimization_alpha(quantum_system, N, n_walkers)
#      50     while abs(difference) >= tol and i < max_it:
#      51         keep = alpha_min
# ---> 52         der_E, E_ground = derivative_E(alpha_min, quantum_system, N, n_walkers)
#      53         alpha_min = alpha_min - gamma * der_E
#      54         alpha_array.append(alpha_min)
#
# ~/project2/Project_2/QMCP/functions/minimal_energy_finder.py in derivative_E(alpha, quantum_system, N, n_walkers)
#       8 def derivative_E(alpha, quantum_system, N, n_walkers):
#       9     f = lambda R: quantum_system.trial_wave_function(alpha, R)
# ---> 10     prob_dens = metropolis(f,N,n_walkers, quantum_system.dimension)
#      11     E = quantum_system.E_loc(alpha, prob_dens)
#      12     E_ground = expectation_value(E)
#
# ~/project2/Project_2/QMCP/functions/metropolis_algorithm.py in metropolis(function, N, n_walkers, dim)
#       8     for i in range(N):
#       9         r_trial = r + (0.1*np.random.randn(dim, n_walkers))
# ---> 10         ratio = (function(r_trial) / function(r))**2
#      11         eta = np.random.uniform(0,1,(dim,n_walkers))
#      12         rn[:,i,:] = np.where(ratio >= 1, r_trial, (np.where(eta < ratio, r_trial, r)))
#
# ~/project2/Project_2/QMCP/functions/minimal_energy_finder.py in <lambda>(R)
#       7
#       8 def derivative_E(alpha, quantum_system, N, n_walkers):
# ----> 9     f = lambda R: quantum_system.trial_wave_function(alpha, R)
#      10     prob_dens = metropolis(f,N,n_walkers, quantum_system.dimension)
#      11     E = quantum_system.E_loc(alpha, prob_dens)
#
# ~/project2/Project_2/QMCP/helium_atom/helium_atom.py in trial_wave_function(self, alpha, r)
#      26         r1 = np.linalg.norm(r[:3], axis = 0)
#      27         r2 = np.linalg.norm(r[3:], axis = 0)
# ---> 28         r12 = np.linalg.norm(r[:3]-r[3:], axis = 0)
#      29         trial_wave = np.exp(-2*r1 - 2*r2 + r12/(2*(1+alpha*r12)))
#      30         return(trial_wave)
#
# /opt/conda/lib/python3.6/site-packages/numpy/linalg/linalg.py in norm(x, ord, axis, keepdims)
#    2151     x = asarray(x)
#    2152
# -> 2153     if not issubclass(x.dtype.type, (inexact, object_)):
#    2154         x = x.astype(float)
#    2155
#
# KeyboardInterrupt:
